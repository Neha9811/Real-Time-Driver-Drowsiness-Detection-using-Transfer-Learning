# %%
#pip install opencv-python

# %%
#pip install pygame

# %%
import cv2
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
from pygame import mixer
import os
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
model = load_model(r'C:\Users\gupta\Project\DenseNet201_Seqn\model.h5')

# %%
# import cv2
# import os
# cascPathface = os.path.dirname(
#     cv2.__file__) + "/data/haarcascade_frontalface_alt2.xml"
# cascPatheyes = os.path.dirname(
#     cv2.__file__) + "/data/haarcascade_eye_tree_eyeglasses.xml"

# faceCascade = cv2.CascadeClassifier(cascPathface)
# eyeCascade = cv2.CascadeClassifier(cascPatheyes)

# video_capture = cv2.VideoCapture(0)
# while True:
#     # Capture frame-by-frame
#     ret, frame = video_capture.read()
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     faces = faceCascade.detectMultiScale(gray,
#                                          scaleFactor=1.1,
#                                          minNeighbors=5,
#                                          minSize=(60, 60),
#                                          flags=cv2.CASCADE_SCALE_IMAGE)
#     eyes = eyeCascade.detectMultiScale(gray,
#                                          scaleFactor=1.1,
#                                          minNeighbors=5,
#                                          minSize=(60, 60),
#                                          flags=cv2.CASCADE_SCALE_IMAGE)
#     for (x,y,w,h) in eyes:
#         roi_gray = gray[y:y+h,x:x+w]
#         roi_color =frame[y:y+h,x:x+w]
#         cv2.rectangle(frame, (x, y), (x + w, y + h),(0,255,0), 2)
#         faceROI = frame[y:y+h,x:x+w]
#         eyess = eyeCascade.detectMultiScale(roi_gray)
#         if len(eyess) == 0:
#             print("Eyes Are not Detected")
#         else:
#             for (ex, ey, ew, eh) in eyess:
#                 eyes_roi = roi_color[ey:ey+eh,ex:ex+ew]
#                 frame = frame[ey:ey+eh,ex:ex+w]
#                 final_image = cv2.resize(eyes_roi,(224,224))
#                 final_image = np.expand_dims(final_image,axis=0)
#                 final_image = final_image/255.0
#                 prediction = model.predict(final_image)
#                 if prediction.any()>0:
#                     status = "Open Eyes"
#                 else:
#                     status ="Closed Eyes"
#     gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#     print(faceCascade.empty())
#     faces = faceCascade.detectMultiScale(gray,1.1,4)
                

#         # Display the resulting frame
#     cv2.imshow('Video', frame)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# video_capture.release()
# cv2.destroyAllWindows()

# %%
# import cv2
# import os
# cascPathface = os.path.dirname(
#     cv2.__file__) + "/data/haarcascade_frontalface_alt2.xml"
# cascPatheyes = os.path.dirname(
#     cv2.__file__) + "/data/haarcascade_eye_tree_eyeglasses.xml"

# faceCascade = cv2.CascadeClassifier(cascPathface)
# eyeCascade = cv2.CascadeClassifier(cascPatheyes)

# video_capture = cv2.VideoCapture(0)
# while True:
#     # Capture frame-by-frame
#     ret, frame = video_capture.read()
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     faces = faceCascade.detectMultiScale(gray,
#                                          scaleFactor=1.1,
#                                          minNeighbors=5,
#                                          minSize=(60, 60),
#                                          flags=cv2.CASCADE_SCALE_IMAGE)
#     for (x,y,w,h) in faces:
#         cv2.rectangle(frame, (x, y), (x + w, y + h),(0,255,0), 2)
#         faceROI = frame[y:y+h,x:x+w]
#         eyes = eyeCascade.detectMultiScale(faceROI)
#         for (x2, y2, w2, h2) in eyes:
#             eye_center = (x + x2 + w2 // 2, y + y2 + h2 // 2)
#             radius = int(round((w2 + h2) * 0.25))
#             frame = cv2.circle(frame, eye_center, radius, (255, 0, 0), 4)

#         # Display the resulting frame
#     cv2.imshow('Video', frame)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# video_capture.release()
# cv2.destroyAllWindows()

# %%
mixer.init()
sound= mixer.Sound(r'C:\Users\gupta\Project\DenseNet201_Seqn\alarm.wav')
cascPathface = os.path.dirname(
    cv2.__file__) + "/data/haarcascade_frontalface_alt2.xml"
cascPatheyes = os.path.dirname(
    cv2.__file__) + "/data/haarcascade_eye_tree_eyeglasses.xml"

faceCascade = cv2.CascadeClassifier(cascPathface)
eyeCascade = cv2.CascadeClassifier(cascPatheyes)
cap = cv2.VideoCapture(0)
Score = 0
while True:
    ret, frame = cap.read()
    height,width = frame.shape[0:2]
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces= faceCascade.detectMultiScale(gray, scaleFactor= 1.2, minNeighbors=3)
    eyes= eyeCascade.detectMultiScale(gray, scaleFactor= 1.1, minNeighbors=1)
    
    cv2.rectangle(frame, (0,height-50),(200,height),(0,0,0),thickness=cv2.FILLED)
    
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,pt1=(x,y),pt2=(x+w,y+h), color= (255,0,0), thickness=3 )
        
    for (ex,ey,ew,eh) in eyes:
        #cv2.rectangle(frame,pt1=(ex,ey),pt2=(ex+ew,ey+eh), color= (255,0,0), thickness=3 )
        
        # preprocessing steps
        eye= frame[ey:ey+eh,ex:ex+w]
        eye= cv2.resize(eye,(224,224))
        eye= eye/255
        eye= eye.reshape(224,224,3)
        eye= np.expand_dims(eye,axis=0)
        # preprocessing is done now model prediction
        prediction = model.predict(eye)
        
        # if eyes are closed
        if prediction[0][0]>0.30:
            cv2.putText(frame,'closed',(10,height-20),fontFace=cv2.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv2.LINE_AA)
            cv2.putText(frame,'Score'+str(Score),(100,height-20),fontFace=cv2.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv2.LINE_AA)
            Score=Score+1
            if(Score>3):
                try:
                    sound.play()
                except:
                    pass
            
        # if eyes are open
        elif prediction[0][1]>0.90:
            cv2.putText(frame,'open',(10,height-20),fontFace=cv2.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv2.LINE_AA)      
            cv2.putText(frame,'Score'+str(Score),(100,height-20),fontFace=cv2.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv2.LINE_AA)
            Score = Score-1
            if (Score<0):
                Score=0
            
        
    cv2.imshow('frame',frame)
    if cv2.waitKey(33) & 0xFF==ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 222ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14172\1715369986.py in <module>
#      15     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      16     faces= faceCascade.detectMultiScale(gray, scaleFactor= 1.2, minNeighbors=3)
# ---> 17     eyes= eyeCascade.detectMultiScale(gray, scaleFactor= 1.1, minNeighbors=1)
#      18
#      19     cv2.rectangle(frame, (0,height-50),(200,height),(0,0,0),thickness=cv2.FILLED)
#
# KeyboardInterrupt:
